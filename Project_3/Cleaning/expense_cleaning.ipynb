# %%
# import dependencies
import pandas as pd

# %%
# load in file
file = "../Resources/athletic_expense_report.csv"

# %%
# turn file into pandas df
expense_data = pd.read_csv(file)
expense_data.head()
# Out:
#                        Data  IPEDS ID  Year  \
# 0  Alabama A & M University    100654  2005
# 1  Alabama A & M University    100654  2006
# 2  Alabama A & M University    100654  2007
# 3  Alabama A & M University    100654  2008
# 4  Alabama A & M University    100654  2009
#
#                     NCAA Subdivision FBS Conference Total Expenses  \
# 0  Football Championship Subdivision            NaN    $4,370,215
# 1  Football Championship Subdivision            NaN    $7,811,439
# 2  Football Championship Subdivision            NaN    $5,355,699
# 3  Football Championship Subdivision            NaN    $6,368,280
# 4  Football Championship Subdivision            NaN    $6,641,301
#
#   Excess Transfers Back Other Expenses    Medical Competition Guarantees  ...  \
# 0                   $0       $128,579    $50,000                $10,000   ...
# 1                   $0       $562,826   $349,608                $37,343   ...
# ...

# %%
# dropping unwanted columns and chaning column names 
expense_data = expense_data.drop('IPEDS ID', axis=1)
expense_data.rename(columns={'Data':'School'})
# Out:
#                            School  Year                   NCAA Subdivision  \
# 0        Alabama A & M University  2005  Football Championship Subdivision
# 1        Alabama A & M University  2006  Football Championship Subdivision
# 2        Alabama A & M University  2007  Football Championship Subdivision
# 3        Alabama A & M University  2008  Football Championship Subdivision
# 4        Alabama A & M University  2009  Football Championship Subdivision
# ...                           ...   ...                                ...
# 3229  Youngstown State University  2014  Football Championship Subdivision
# 3230  Youngstown State University  2015  Football Championship Subdivision
# 3231  Youngstown State University  2016  Football Championship Subdivision
# 3232  Youngstown State University  2017  Football Championship Subdivision
# 3233  Youngstown State University  2018  Football Championship Subdivision
#
# ...

# %%
expense_data.columns
# Out:
# Index(['Data', 'Year', 'NCAA Subdivision', 'FBS Conference', 'Total Expenses',
#        'Excess Transfers Back', 'Other Expenses', 'Medical',
#        'Competition Guarantees', 'Recruiting', 'Game Expenses and Travel',
#        'Facilities and Equipment', 'Coaches Compensation',
#        'Support and Admin Compensation w/Severance', 'Athletic Student Aid',
#        'Total Revenues', 'Other Revenue',
#        'Corporate Sponsorship, Advertising, Licensing', 'Donor Contributions',
#        'Competition Guarantees.1',
#        'NCAA/Conference Distributions, Media Rights, and Post-Season Football',
#        'Ticket Sales', 'Institutional/Government Support', 'Student Fees',
#        'Total Institutional/Government Support and Student Fees',
#        'Total Academic Spending (University-Wide)', 'Total Football Spending',
#        'Total Football Coaching Salaries', 'Athletics Related Debt',
#        'Annual Debt Service, Leases and Rental Fees on Athletic Facilities'],
# ...

# %%
schools_wanted = expense_data['Data'].unique()
schools = list(schools_wanted)
len(schools)
# Out:
# 231

# %%
# saving new_csv
# expense_data.to_csv('../Cleaned_Resources/expense_data.csv')
