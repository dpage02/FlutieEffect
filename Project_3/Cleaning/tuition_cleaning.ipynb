# %%
# import dependencies
import pandas as pd

# %%
# load in file
tuition_file = "../Resources/tuition_trends.csv"
expense_file = "../Resources/athletic_expense_report.csv"

# %%
# turn file into pandas df
expense_data = pd.read_csv(expense_file)
tuition_data = pd.read_csv(tuition_file)


# expense_data.head()
tuition_data.head()
# Out:
#    Unnamed: 0                           Unnamed: 1  \
# 0      100654             Alabama A & M University
# 1      100654             Alabama A & M University
# 2      100654             Alabama A & M University
# 3      100654             Alabama A & M University
# 4      100663  University of Alabama at Birmingham
#
#                                    Unnamed: 2     2019     2018     2017  \
# 0                   On-campus in-state(total)  23954.0  23462.0  23057.0
# 1   Off-campus with family in-district(total)  14714.0  14334.0  14037.0
# 2      Off-campus with family in-state(total)  14714.0  14334.0  14037.0
# 3  Off-campus with family out-of-state(total)  23324.0  22944.0  22416.0
# 4                   On-campus in-state(total)  27630.0  26336.0  26096.0
#
#       2016     2015     2014     2013  ...     2011     2010     2009  \
# 0  22886.0  22896.0  20884.0  21849.0  ...  17688.0  15210.0  13922.0
# 1  14056.0  14756.0  12196.0  10282.0  ...   9928.0   8900.0   7792.0
# ...

# %%
tuition_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', '2019', '2018', '2017',
#        '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008',
#        '2007', '2006', '2005', '2004', '2003', '2002'],
#       dtype='object')

# %%
# recreating football schools list 
schools_wanted = expense_data['Data'].unique()
football_schools = list(schools_wanted)
len(schools_wanted)
# print(football_schools)
# Out:
# 231

# %%
# dataframe of schools that are in football list
tuition_df = tuition_data[tuition_data['Unnamed: 1'].isin(football_schools)]
tuition_df
# Out:
#       Unnamed: 0                           Unnamed: 1  \
# 0         100654             Alabama A & M University
# 1         100654             Alabama A & M University
# 2         100654             Alabama A & M University
# 3         100654             Alabama A & M University
# 4         100663  University of Alabama at Birmingham
# ...          ...                                  ...
# 3271      433660        Florida Gulf Coast University
# 3912      486840            Kennesaw State University
# 3913      486840            Kennesaw State University
# 3914      486840            Kennesaw State University
# 3915      486840            Kennesaw State University
#
#                                       Unnamed: 2     2019     2018     2017  \
# 0                      On-campus in-state(total)  23954.0  23462.0  23057.0
# 1      Off-campus with family in-district(total)  14714.0  14334.0  14037.0
# 2         Off-campus with family in-state(total)  14714.0  14334.0  14037.0
# ...

# %%
# getting list of schools that are in the tuition dataframe
tuition_list = list(tuition_df['Unnamed: 1'].unique())
# tuition_list

# %%
# shows what schools from football list are missing 
missing_schools = list(set(football_schools) - set(tuition_list))
missing_schools
# Out:
# ['The University of Tennessee at Martin',
#  'University of New Hampshire',
#  'The University of Tennessee',
#  'Oklahoma State University',
#  'Binghamton University, The State University of New York',
#  'The Ohio State University',
#  'United States Air Force Academy',
#  'Rutgers, The State University of New Jersey-New Brunswick',
#  'University at Buffalo, The State University of New York',
#  'Ohio University',
#  'University of South Carolina',
#  'University of Michigan',
#  'University of New Mexico',
#  'North Dakota State University',
#  'University of Washington',
#  'Pennsylvania State University',
#  'College of William and Mary',
#  'Wright State University',
#  'University of Cincinnati',
#  'Missouri State University',
#  'Purdue University',
#  'Kent State University',
#  'University of South Carolina Upstate',
#  'University at Albany, State University of New York',
#  'University of South Florida',
#  'Arizona State University',
#  'Miami University',
# ...

# %%
# dropping unwanted columns and chaning column names 
tuition_data = tuition_df.drop('Unnamed: 0', axis=1)
tuition_data = tuition_df.rename(columns={'Unnamed: 1':'School', 'Unnamed: 2':'Living_Type'})
tuition_data
# Out:
#       Unnamed: 0                               School  \
# 0         100654             Alabama A & M University
# 1         100654             Alabama A & M University
# 2         100654             Alabama A & M University
# 3         100654             Alabama A & M University
# 4         100663  University of Alabama at Birmingham
# ...          ...                                  ...
# 3271      433660        Florida Gulf Coast University
# 3912      486840            Kennesaw State University
# 3913      486840            Kennesaw State University
# 3914      486840            Kennesaw State University
# 3915      486840            Kennesaw State University
#
#                                      Living_Type     2019     2018     2017  \
# 0                      On-campus in-state(total)  23954.0  23462.0  23057.0
# 1      Off-campus with family in-district(total)  14714.0  14334.0  14037.0
# 2         Off-campus with family in-state(total)  14714.0  14334.0  14037.0
# ...

# %%
tuition_schools = list(tuition_data['School'].unique())
len(tuition_schools)
# Out:
# 191

# %%
# saving new_csv
tuition_data.to_csv('../Cleaned_Resources/tuition_data.csv')
